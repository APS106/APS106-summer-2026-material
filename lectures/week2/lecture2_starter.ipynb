# %% [markdown]
# # Week 2 | Lecture 2
#
# ## Sections
# 1. [Function Review](#section1)
# 2. [While Loops](#section2)
# 3. [Random Module](#section3)
# 4. [Intro to Objects](#section4)
# 5. [Strings](#section5)

# %% [markdown]
# <a id='section1'></a>
# ## Function Review
# Let's consider a use case for writing multiple functions. Let's say you want to write functions to calculate the volume and surface area of a cylinder.
#
# We will need the math module so let's import it.

# %%
import math

def circle_area(radius):
    """
    (number) -> number
    Calculates the area of a circle given the radius.
    """
    return math.pi * radius**2

def circle_circumference(radius):
    """
    (number) -> number
    Calculates the circumference of a circle given the radius.
    """
    return 2 * math.pi * radius

def cylinder_volume(radius, height):
    """
    (number, number) -> number
    Calculates the volume of a cylinder given the radius and height.
    """
    area = circle_area(radius) 
    return area * height

def cylinder_surface_area(radius, height):
    """
    (number, number) -> number
    Calculates the surface area of a cylinder given the radius and height.
    """
    circumference = circle_circumference(radius)
    area = circle_area(radius)
    return circumference * height + 2 * area

# %% [markdown]
# Now, let's compute the volume and surface area of a cylinder with `length` and `height`.

# %%
radius = 1
height = 1

volume = cylinder_volume(radius, height)
print('The volume is', volume)

area = cylinder_surface_area(radius, height)
print('The surface area is', area)

# %% [markdown]
# If `print` and `return` were the same thing, we should be able to replace the `return` statements with `print` statements and the functions should work as expected.

# %%
import math

def circle_area(radius):
    """
    (number) -> number
    Calculates the area of a circle given the radius.
    """
    print(math.pi * radius**2)

def circle_circumference(radius):
    """
    (number) -> number
    Calculates the circumference of a circle given the radius.
    """
    print(2 * math.pi * radius)

def cylinder_volume(radius, height):
    """
    (number, number) -> number
    Calculates the volume of a cylinder given the radius and height.
    """
    area = circle_area(radius) 
    print(area * height)

def cylinder_surface_area(radius, height):
    """
    (number, number) -> number
    Calculates the surface area of a cylinder given the radius and height.
    """
    circumference = circle_circumference(radius)
    area = circle_area(radius)
    print(circumference * height + 2 * area)

# %% [markdown]
# Now, let's compute the volume and surface area of a cylinder with `length` and `height`.

# %%
radius = 1
height = 1

volume = cylinder_volume(radius, height)
print('The volume is', volume)

area = cylinder_surface_area(radius, height)
print('The surface area is', area)

# %% [markdown]
# ## When is a function done?
#
# A function finishes running either when all indented code has been executed OR a return statement was executed.
#
# #### What line is the last to be executed when this function is called and what does it return?

# %%
def func(x):
    x+=1
    x+=1
    x+=1
    return x

# %%
out = func(1)
print(out)

# %% [markdown]
# #### What line is the last to be executed when this function is called and what does it return?

# %%
def func(x):
    x+=1
    x+=1
    x+=1
    x-=1
    x/=1
    return x
    x+=1
    x+=1
    x+=1

# %%
out = func(1)
print(out)

# %% [markdown]
# #### What line is the last to be executed when this function is called and what does it return?

# %%
def func(x):
    if x == 0:
        return x
    if x < 1:
        return x
    if x >= 1:
        x+=1
    else:
        return x

# %%
out = func(1)
print(out)

# %% [markdown]
# <a id='section2'></a>
# ## While Loops
#
# Looping means repeating something over and over until a particular condition is satisfied. Sometimes we need to keep looping as long as some condition is True, and stop when it becomes False.
#
# The form of a while-loop is:
#
# ```python
# while expression:
#     body
# ```
#
# `expression` is a boolean expression: it evaluates to `True` or `False`. While it is `True` the code in `body` is executed and then the execution returns to the `while` line and evaluates `expression` again. If it is still `True`, execute `body`, loop back, and test `expression` again. If `expression` is `False`, skip `body` and go to the next line after it.
#
# **Key Ideas**:
#
#     - Need a way to change condition so there is no infinite loops
#     - Lazy evaluation applies here as well
#
# How can we use a while-loop to print the integers between 0 and 9?

# %%
x = 0
while x < 10:
    print('x is now:', x)
    x += 1
    
print('\nFinished')
print('x =', x)

# %% [markdown]
# Wow, that was fast! Let's slow things down so we can see what's going on.

# %%
import time

x = 0
print('x is initially set to:', x)

print('Starting While loop\n')
while x < 10:
    
    time.sleep(1.5)
    print('Starting an iteration, x =', x)
    
    time.sleep(1.5)
    print('Updating x,', x, '+ 1 = ', x + 1)
    x += 1
    
    time.sleep(1.5)
    if x < 10:
        print('Condition', x, '< 10 is True')
        print('Continuing to next iteration\n')
    else:
        print('Condition', x, '< 10 is False')
        print('Exiting While loop')

# %% [markdown]
# How many printouts will the following while loop produce?

# %%
x = 1
while x < 4:
    print(x)
    x = x + 1

# %% [markdown]
# ## Infinite Loops
# Let's go back to our original code and remove the indentation of `x +=1`.
#
# What do you think will happen?

# %%
x = 0
while x < 10:
    print('x is now:', x)

# %% [markdown]
# Yikes! Click the `stop` button to break out of the loop.
#
# **Takeaway: you must always update the condition being checked in a while loop somehow.**

# %% [markdown]
# # Breakout Session
# Write a code to print all the numbers from 1 to 20 that aren’t evenly divisible by either 3 or 5.
#
# Zero is divisible by everything and should not appear in the output.
#
# Your code should output the following:
# ```python
# 1
# 2
# 4
# 7
# 8
# 11
# 13
# 14
# 16
# 17
# 19
# ```

# %%
# Write your code here

# %% [markdown]
# ## While loops and User Input
# If I have the following code below, how can we use a `while` loop to keep asking the user the question until they answer `'y'` or `'n'`?

# %%
answer = input("Do you think the Toronto Maple Leafs will win the Stanley Cup in your lifetime? (y/n): ")

if answer == 'y':
    print("You are going to live for a very long time.")
elif answer == 'n':
    print("Well, sometimes miracles happen.")
else:
    print("Sorry, that was not one of the options.")

# %% [markdown]
# We can use a `while` loop to continue asking the question `"Do you think the Toronto Maple Leafs will win the Stanley Cup in your lifetime? (y/n): "` until the user enters `'y'` or `'n'`.

# %%
answer = input("Do you think the Toronto Maple Leafs will win the Stanley Cup in your lifetime? (y/n): ")

# Write code to ask the user for an answer until they input a valid response ('y' or 'n')
...
    
if answer == 'y':
    print("You are going to live for a very long time.")
else:
    print("Well, sometimes miracles happen.")

# %% [markdown]
# ### Lazy Evaluation
# Just like for if-statements, if you use `and` or `or` in a while-loop `expression`, it is subject to lazy evaluation.

# %%
def my_func(x):
    print("Inside my_func, x =", x)
    return True

# %%
x = 13
while x > 10 and my_func(x):
    #print(x)
    x = x - 1

# %%
x = 13
while my_func(x) and x > 10:
    #print(x)
    x = x - 1

# %% [markdown]
# <a id='section3'></a>
# ## Random Module
# So far, we have only imported the math moduel. Let's now learn another useful module called the `random` module.

# %%
import random

# %% [markdown]
# Check out the `help` function.

# %%
help(random)

# %% [markdown]
# #### `randint(a, b)`
# Return a random integer N such that a <= N <= b.

# %%
random.randint(5, 10)

# %% [markdown]
# #### `random()`
# Return the next random floating point number in the range 0.0 to 1.0.

# %%
random.random()

# %% [markdown]
# # Breakout Session
# You are rolling a six-sided die, but there's a problem: you keep rolling unlucky numbers! Write a function `roll_until_lucky(lucky_number)` that:
#
# - Starts by rolling a six-sided die (`random.randint(1, 6)`).
# - Continues rolling until the lucky number appears.
# - Prints each roll along the way.
# - Finally, when the lucky number appears, prints `"Lucky roll! Stopping now."`.
#
# **Example (lucky number = 5):**
# ```python
# >>> roll_until_lucky(5)
# Rolling... 3
# Rolling... 1
# Rolling... 6
# Rolling... 5
# Lucky roll! Stopping now.
# ```

# %%
import random

def roll_until_lucky(lucky_number):
    
    """
    (int) -> None
    Write a function that roles a 6 sided dice until lucky_number is rolled.
    """
    roll = random.randint(1, 6) 
    while ...
    
    print("Lucky roll! Stopping now.")

# %% [markdown]
# Let's try our function.

# %%
roll_until_lucky(4)

# %% [markdown]
# # Breakout Session - A Guessing Game
#
# Write code that:
# - Gets the computer to choose a random integer from 0 to 100.
# - Gets a user to enter either a guess of this number or 'q' to exit
# - Tells the user after each guess whether they guessed correctly.
# - If they guessed incorrectly, tell them whether the guess is higher or lower than the actual number
# - Continue to prompt the user to guess until they guess the number (or enter 'q')

# %%
# Write code here
# Start with pseudo code!!!

# %% [markdown]
# <a id='section4'></a>
# ## Intro to Objects
#
# ### Everything is an Object
# Everything in Python is an object. We will learn more about this when we talk about 'Object-Oriented Programming' and you start making your own classes (like making your own 'type' similar to type int and type float). You actually already saw an example of this in Lab 1 when you were working with the Turtle class, but we will explain that in more detail later.
#
# For now, it is important to know that every Python object has certain functions that can only be applied to that object (called **methods**.) The basic way to think of a method is something that an object can do (or something you can ask an object to do).
#
# Calling methods is similar to calling functions with one minor difference. Since methods are applied to objects, we need to provide the object name with a “.” before the method name.
#
#     function_name(arguments)
#     object_name.method_name(arguments)

# %% [markdown]
# <a id='section5'></a>
# ## Strings
# ### Strings are also Objects!
#
# This means that string objects have certain methods that we can use:

# %%
help(str)

# %%
my_str = "Today is the first day of the week: Monday"
num_day = my_str.count("day")
print(num_day)

# %%
start_day = my_str.find("day")
print(start_day)

# %% [markdown]
# We will talk about more of these string methods next week.
#
# ## Escape Sequences
# What if you wanted to str variables to be equal to “Don’t forget to buy milk”?

# %%
reminder = 'Don't forget to buy that NFT.'
print(reminder)

# %% [markdown]
# What is the problem here?
#
# One way to get around the problem is to use double-quotes.

# %%
reminder = "Don't forget to buy that NFT."
print(reminder)

# %% [markdown]
# Similarly, you can print "He replied, "My name is LeBron."" by using single quotes.

# %%
response = 'He replied, "My name is LeBron."'
print(response)

# %% [markdown]
# OK, but what about:
#
# "Don't forget to buy that NFT," LeBron screamed.
#
# including the quotes, apostrophe, and period?

# %%
angry_man = "\"Don't forget to buy that NFT,\" LeBron screamed."
print(angry_man)

# %% [markdown]
# You can include a special character (like ' or ") by using the _escape character_: `\`. Using `\` means "consider the next character as part of the string, not a special character."
#
# Q: If \ is the escape character, then how do you include the \ character in a string?

# %%
escape = "The escape character in Python is \\. Double backslash: \\\\"
print(escape)

# %% [markdown]
# The `\` character and the character that follows are called an _escape sequence_. Here are a few
#
#  | Escape Sequence | Meaning |
#  |-----------------|---------|
#  |\n               | newline |
#  |\t               | tab     |

# %%
three_lines = 'This string\nwill print on two lines\nwait now it\'s three lines with a tab\there'
print(three_lines)

# %% [markdown]
# <a id='section3'></a>
# ### String Operators
# Just like numbers strings have "operators" like +, *, etc.

# %%
name = "Seb"
message = "Happy Birthday " + name
print(message)

# %% [markdown]
# **We will highlight this more later, but you cannot use + between a str and an int or float. You can only add two strings together or two numbers together.**

# %%
name = 'Sina' * 5
print(name)

# %%
name = 3 * "Tanishka"
print(name)

# %%
cat_dog = 'cat' + 'dog' * 2
print(cat_dog)

# %% [markdown]
#  | Expression | Description |
#  |------------|-------------|
#  |st1 + str2  |concatenate str1 and str2           |
#  |str1 * int1 |concatenate int1 copies of str1     |
#  |int1 * str1 |concatenate int1 copies of str1     |
#
#  "concatenate" means to put things together in a sequence.
#
#  What about other operators: -, \\? They're not defined.

# %%
name = "Mark" - 'k'

# %% [markdown]
# # Breakout Session
#
# Write a function, without using a loop, to create a string the repeats “Happy Birthday [NAME]” as many times as the age of the person?

# %%
def happy_bday(name, age):
    '''
    (str, int) -> str
    Returns a str that repeats "Happy Birthday <name>\n" age times
    '''

# %%
#Test Case

long_str = happy_bday("Seb", 29)
print(long_str)

# %% [markdown]
# <a id='section4'></a>
# ## Type Conversions
# **Convert to str**
#
# The builtin function `str` takes any value and returns a string representation of that value.

# %%
str(2)
my_str = str(2) + str(2)
print(my_str)

# %%
x = str(42.8)
print(x)     #even though this looks like a float, it's actually a string
print(type(x))

# %% [markdown]
# **Convert to int**

# %%
y = int('12345')
print(y)
print(type(y))

print(int('-99'))
print(int('99.9'))
print(int(99.9))

# %% [markdown]
# If function `int` is called with a string that contains anything other than digits, a `ValueError` happens.
#
# **Convert to float**

# %%
print(float('99.9'))
print(int(float('99.9')))
print(float('-43.2'))
print(float('453'))

# %% [markdown]
# If function `float` is called with a string that can't be converted, a `ValueError` happens.

# %%
print(float('-9.9.9.9.9.9.9'))

# %% [markdown]
# # Breakout Session
#
# Ask the user how many times they would like to see the string ”knock knock knock… Penny” repeated.  Then, print it!
#
# Try not to use loops (instead use String tools you learned today).  Are you able to customize the name?!
#
# **Hints for getting started:**
#
# Ask the user for a number of times (think: input function)
#
# Remember input function returns a string…
#
# Repeated string (think: concatenation, * operator might be useful)
#
# Make the output readable (think: escape characters)

# %%
#Breakout session here - can you do it in less than 4 lines?
