# %% [markdown]
# # Week 1 | Lecture 1

# %% [markdown]
# Welcome to your first APS106 notebook! These notebooks will be used to reinforce the content we learn in class by going through examples together.
#
# ## Sections:
# 1. [Jupyter Notebook Demo](#section1)
# 2. [Variables and Memory](#section2)
# 3. [Different Types of Variables](#section3)
# 4. [Expressions and Operators](#section4)
# 5. [Augmented Assignment Operators](#section5)

# %% [markdown]
# <a id='section1'></a>
# # 1. Jupyter Notebook Demo
#
# Jupyter Notebooks are split into discrete "cells".  This is a cell, and so is the block of text above, and the piece of Python code below.
#
# Each cell can be run indepedently by hitting the Run button in the top toolbar or going to Run -> Run All Cells
#
# Cells can either be a "Code" cell, or a "Markdown" cell.  To change a cell type, highlight that cell, and select the type you want within the dropdown menu above (that either says "Code" or "Markdown")
#
# Markdown is a popular markup language similar to HTML, and is used in Jupyter Notebooks to supplement them with text, images, and other visualisations.  This cell, and the cell above (containing the title and Lecture Structure), are both Markdown cells.
#
# Code cells contain executable Python code, as seen below:

# %% [markdown]
# **Comments are text that is ignored when a program is run.**
#
# **The print() statement displays output to the screen.**

# %%
# anything after a hashtag (#) is called a 'comment' and is ignored by Python

print("Hello World") #this cell can be executed (or run) by hitting the Run button or pressing shift enter

# %% [markdown]
# Notice how the message we wanted to 'print out' was displayed below the cell that was executed.
#
# To execute all cells in the Notebook at once, you can select Run -> Run All Cells
#
# You can also choose to run only the cells above or below the cell you have selected.

# %%
print("This will print,")

# %%
print("so will this...")

# %%
print("and so will this!")

# %% [markdown]
# Click on this cell and select Cell -> Run All Above to see all 3 cells execute and output something below.

# %% [markdown]
# ## Clearing Output vs. Restarting the Kernel
#
# After executing the 3 print statements above, select Edit -> Clear Outputs of All Cells.
#
# Notice anything?  This clears everything that has been output or displayed in your Notebook.
#
# HOWEVER, this only clears what has been output and does not clear your memory.  In order to wipe current data you need to restart the kernel. By restarting the kernel, you will get a clean slate of memory to work with.
#
# You may also need to restart your kernel if you find Jupyter unresponsive (or stuck in an infinite loop).
#
# To restart your kernel, select Kernel -> Restart Kernel.

# %% [markdown]
# ## Order of Execution Matters
#
# In a .py file, everything runs in sequence and as written.  In a Jupyter Notebook, the executing cells out of order (if not running them all from start to finish) can lead to unexpected and unintended errors.
#
# Run the cells below in the following sequence:
# CELL 1 ->
# CELL 2 ->
# CELL 3 ->
# CELL 2
#
# Notice the name changes the second time we run Cell 2.  Be careful - running cells out of order can lead to confusing errors that are hard to de-bug.

# %%
#CELL 1

name = 'Tanishka'

# %%
#CELL 2

print("Hi", name)

# %%
#CELL 3

name = 'Sina'

# %% [markdown]
# ## Moving Cells
#
# You can move cells by selecting them and then by using the Up and Down arrows on the top right of the Cell or in the toolbar above.
#
# ## Use Keyboard Shortcuts
#
# Click on the Help dropdown menu and select Keyboard shortcuts to see what is available.
#
# Aside from Shift-Enter to execute cells, another common shortcut is double pressing the D key to delete a cell.  Highlight the cell below and give it a try.  You can always go to Edit -> Undo if you need to.

# %%
#Delete me by pressing the d key twice!

# %% [markdown]
# <a id='section2'></a>
#
# # 2. Variables and Memory
#
# **Variables store information (values) in an accessible way.**
#
# The most basic thing you can do in a computer program is to assign a value to a variable.
# Here are three lines in a Python program. Each line does 3 things:
# - creates a variable
# - gives it a name
# - assigns a value

# %%
base = 20
height = 12
area = base*height

# %% [markdown]
# So now we have a variable named `base` with a value of 20 and a variable named `height` with a value of 12.  There is also a variable named area with a value of 20 x 12 (which equals 240).  But we didn't get any output?!
#
# ## Output: The `print` statement
#
# You will have noticed when I ran the above code, it didn't look like anything happened. Stuff did happen (as described above) but since there was no output, you couldn't tell.
#
# We'll get into this in (much more) depth later in the course. For now, you should know that there exists a function called `print` which prints a value to the screen. Whenever you need to output something, you will need to use a `print` function.

# %%
print(area)

# %% [markdown]
# ## Variable Names
#
# Python has a two rules for legal variable names:
# 1. Names must start with a letter or \_ (an underscore).
# 2. Names must contain only letters, digits, and \_ (no special characters).
#
# By convention, it is good Python style to use `pothole_case`. Create meaningful variables names with underscore separating the "words" in the name (if there is more than one meaningful word).

# %%
family_name = "Smith" 
learning_rate = 0.01

# %% [markdown]
# ## Assignment Statements
#
# *Everything* in Python has a location in memory. **This is different than most languages!** Each location in memory has an *address*. You can think of this as similar to a house address. Just as "40 St. George St" refers to a location in Toronto, each location has a corresponding "id" which maps to its location in memory.
#
# An assignment statement is always executed as follows:
# 1. The expression to the right of the `=` sign is evaluated. "Evaluated" means that the computer figures out what quantity it represents. That quantity is someplace in memory (i.e., it has a memory address) and that address is figured out.
# 2. The memory address of the evaluated expression is then stored in the variable on the left side of the `=` sign.
#
# The notion of evaluation may sound strange at the moment because a numeric constant (like 20) just evaluates to itself. So it seems like this is more complicated than it has to be. As we will see, we can have more than just a constant on the right-hand side of an assignment. And memorizing the following rule will help you in those more complicated cases:
#
# **First evaluate the thing on the right of =, then assign its address to the thing on the left.**
#
# Let's go through a simple example.
#
# Following our rule, the thing in the right of the `=` is evaluated (to 20, obviously) and then it's address is figured out. The address of 20 is:

# %%
difference = 20
print(difference)

print(id(difference))
print(id(20))

# %%
difference = 5
print(id(difference))
print(id(5))
print(id(20))
print(id(base))

# %% [markdown]
# <a id='section3'></a>
# ## 3. Different Types of Variables
#
# So far we've mostly seen examples of assigning numbers to variables. And mostly, we've only seen a sub-class of numbers being assigned: integers.
#
# A *type* is a set of values and a set of operations that can be performed on the values. To start, let's talk about 3 types of variables:
#
# **Int type represents whole numbers (no decimals)**
#
# **Float type represents continuous numbers (decimals)**
#
# **String (str) represents a string of characters (usually text but not always)**
#
#
# ### Types `int` and `float`
#
# Numeric values are represented in Python as `int` and `float` type.

# %%
approx_time = 13
print(approx_time)
print(type(approx_time))

# %%
time = 13.4
print(time)
print(type(time))

# %% [markdown]
# ### Type `str`
#
# A *string literal* is a sequence of characters. In Python, this type is called `str`. Strings in Python start and end with a single quotes (') or double quotes ("). Just remember that you need to start and end a string literal with the same quote mark. A string can be made up of letters, numbers, and special characters. For example:

# %%
greeting = 'hello'
print(greeting)
print("hello again") 
print(type(greeting))

# %% [markdown]
# If you start a string with a single-quote you need to end it with a single-quote. Similarly, if it starts with a double-quote, a double-quote ends it.

# %%
welcome = "Welcome to 'APS106'!"
print(welcome)

# %%
bad_str = 'Start and end"
print(bad_str)

# %% [markdown]
# <a id='section4'></a>
# ## 4. Expressions and Operators
#
# You already know about mathematical expressions like `2+5-13`. Such expressions: evaluate to some value and are made up of *operators* (e.g., +, -) and *operands* (the values that the operators operate on).
#
# Actually, expressions do not have to have operators. A number by itself or a variable is an expression. When we talked about evaluating the thing after the = sign in an assignment statement, that thing is an expression. So this means we can expand our assignment statements to have any expression on the right-hand side.

# %%
base = 20
height = 12
area = base * height / 2
print(area)

# %%
celsius = 26
fahrenheit = celsius * 9/5 + 32
print(fahrenheit)

# %% [markdown]
# Notice that the examples above have a variable to the right of the = sign. This is fine as a variable will just evaluate to the value that it has been assigned.
#
# The rules for figuring out what assignments statements are doing remain the same. The change is that the evaluation of the expression on the right-hand side is more complicated when you have something other than a number.

# %% [markdown]
# ### Arithmetic Operators
#
# | Operator | Operation | Expression | English | Result |
# | --- | --- | --- | --- | --- |
# | + | addition | 11 + 23 | 11 plus 23 | 34 |
# | - | subtraction | 23 - 52 | 23 minus 52 | -29 |
# | * | multiplication | 4 * 5 | 4 times 5 | 20 |
# | / | division | 9 / 2 | 9 divided by 2 | 4.5 |
# | // | integer division | 9 // 2 | 9 divided by 2 | 4 |
# | ** | exponentiation | 2 ** 5 | 2 to the power 5 | 32 |
# | % | modulo (remainder) | 9 % 2 | 9 mod 2 | 1 |
#
# The first 3 (addition, subtraction, multiplication) should be easy - with the slight issue that multiplication is represented by `*`. This is pretty common in (almost) all programming languages.
#
# ### Division
#
# Division comes in two flavours.
#
# First, the `/` operator divides a number by another number (integer or decimal) and returns and represents the result **as a `float`** (even if there is no remainder).
#
# The second division operator is integer division. It divides the first number by the second with the result being **truncated** (not rounded) to an integer value. "Truncated" means that everything after the decimal is thrown away.
#
# If the two operands of `//` (the two numbers being divided) are both `int`, then the result will be an `int`. If either of the two operands is a `float`, then the result will be a `float` (even though it will have a whole number value).
#
#
# ### Modulo
#
# The last operator may be new to you. It is the modulo operator repesented by `%`. It is also a kind of division but it results in the **remainder** after dividing the operands.

# %%
3+4

# %%
4*5

# %%
10/3

# %%
10/2

# %%
10//3

# %%
2**3

# %%
10%3

# %%
x = 9 / 2
print(x)
y = x / 5
print(y)

# %% [markdown]
# ### Arithmetic Operator Precedence
#
# Just as you learned in high school, when you have a complicated expression some of the operators are executed before others. In Python the operator precedence is as follows.
#
# | Operator | Precedence |
# | --- | --- |
# | ** | highest |
# | - (negation) | |
# | \*, /, //, % | (evaluate left-to-right) |
# | + (addition, - (subtraction) | lowest (evaluate left-to-right) |

# %%
x = 2
y = x % 10 * 3 + 36 / 6
print(y)

# %% [markdown]
# You can use parenthesis to over-ride the default precedence and this is often a good idea in order to write code that can be understood.

# %%
y = x % 10 * (3 + 36) / 6
print(y)

# %%
#celsius = (fahrenheit-32) / (9/5)

fahr = 212
celsius = (fahr - 32) / (9/5)
print(celsius)

# %%
-3**2 #'negation' is after exponentiation in order of precedence

# %% [markdown]
# <a id='section5'></a>
# ## 5. Augmented Assignment Operators
#
#
# | Operator | Expression | Identical Expression |
# | --- | --- | --- |
# | += | x += 2 | x = x + 2 |
# | -= | x -= 3 | x = x - 3 |
# | \*= | x \*= 5 | x = x * 5 |
# | /= | x /= 2 | x = x / 2 |
# | //= | x //= 2 | x = x // 2 |
# | \*\*= | x \*\*= 3 | x = x ** 3 |
# | %= | x %= 3 | x = x % 3 |
#
#
# It is often the case that we want to evaluate some expression using a variable and store that calculation back in the same variable. For example, if you wanted to count something (like the number of perfect squares less than or equal to some number that a user enters), it makes sense to add one to a variable every time you find another perfect square.
#
# Let's write that code.

# %%
max_num = 5  

base = 1
count = 0
while base * base <= max_num:
    count = count + 1
    base = base + 1

print("There are", count, "perfect squares less than", max_num)

# %% [markdown]
# We can re-write the above code using "augmented operators" that combine `+` and `=`.

# %%
max_num = 5

base = 1
count = 0
while base * base <= max_num:
    count += 1
    base += 1

print("There are", count, "perfect squares less than", max_num)

# %% [markdown]
# This code does exactly the same thing: we've just abbreviated by using augmented operators.

# %% [markdown]
# We can do this with all the standard arithmetic operators.

# %%
x = 17
x //= 3  
print(x)

# %%
y = 7
y *= 2  #y = y * 2
print(y)

# %%
z = 20
z %= 6
print(z)

# %%
# Remember: evaluate right hand side of equation first

x = 7
y = 3
x += y**2 - (4 * 3) - y  
print(x)

# %% [markdown]
# The standard rules apply: evaluate the expression on the right-hand side and then increment (in the case of `+=`) the variable on the left-hand side.
