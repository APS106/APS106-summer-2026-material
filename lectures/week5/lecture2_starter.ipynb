# %% [markdown]
# # Week 5 | Lecture 2
#
# ## Sections
# 1. [Tuples](#section1)
# 2. [Tuples Are Immutable](#section2)
# 3. [Unpacking Tuples](#section3)
# 4. [Tuples as return Values](#section4)
# 5. [Sets](#section5)
# 6. [Dictionaries](#section6)
# 7. [Dictionary Operations](#section7)
# 8. [Dictionary Methods](#section8)
# 9. [Iterating](#section9)
# 10. [Dictionary Inversion](#section10)
# 11. [Dictionaries as Data Structures](#section11)

# %% [markdown]
# <a id='section1'></a>
# ## Tuples
#
# A tuple is an ordered, finite sequence of elements.
#
# ### Tuple Assignment
#
# Parentheses are optional but to avoid confusion, it is best to use them.

# %%
nums = 1, 2, 3, 4, 5, 6
print(nums, type(nums))

nums = (1, 2, 3, 4, 5, 6)
print(nums, type(nums))

# %% [markdown]
# There are however some cases where you must your parantheses.

# %%
name = 'Sebastian'
age = 36
phone_number = '555-6283'
print(name, age, phone_number)

# %% [markdown]
# The `print()` function inperprets this as 3 separate variables. So, if we want to print a `tuple` we need to include the parentheses.

# %%
print((name, age, phone_number))

# %% [markdown]
# A tuple with a single element is written as `(x,)` to not be confused with arithmetic operations such as `(4 + 7)`.

# %%
x = (1)
print(x, type(x))

# %%
y = (1,)
print(y, type(y))

# %%
z = (4+7)
print(z, type(z))

# %%
w = (4+7,)
print(w, type(w))

# %% [markdown]
# ### Tuple Operations
#
# For your reference, here are some common sequence operators that work with `tuples`.
#
# | Operation | Result |
# | --- | --- |
# | `x in s` | `True` if an item of *s* is equal to *x*, else `False` |
# | `x not in s` | `False` if an item of *s* is equal to *x*, else `True` |
# | `s + t` | the concatenation of *s* and *t* |
# | `s * n or n * s` | equivalent to adding *s* to itself *n* times |
# | `s[i]` | ith item of *s*, origin 0 |
# | `s[i:j]` | slice of *s* from *i* to *j* |
# | `s[i:j:k]` | slice of *s* from *i* to *j* with step *k* |
# | `len(s)` | length of *s* |
# | `min(s)` | smallest item of *s* |
# | `max(s)` | largest item of *s* |
# | `s.index(x[, i[, j]])` | index of the first occurrence of *x* in *s* (at or after index *i* and before index *j*) |
# | `s.count(x)` | total number of occurrences of *x* in *s* |

# %%
nums = (1, 2, 3, 4, 5, 6, 2)
print(nums)

# %% [markdown]
# Because `tuples` are ordered sequence of data, we can use index operators.

# %%
print(nums[0])

# %%
print(nums[-1])

# %%
print(nums[0:-1:2])

# %%
print(max(nums))

# %%
print(len(nums))

# %%
print(nums.count(2))

# %% [markdown]
# Another example using the members of [The Beatles](https://www.youtube.com/watch?v=NCtzkaL2t_Y).

# %%
beatles = ("john", "paul", "george", "ringo")
print(beatles)
print(beatles[-1])

# %%
'sebastian' in beatles

# %% [markdown]
# Using a `for` loops with `tuples`.

# %%
for name in beatles:
    print(name)

# %% [markdown]
# And using `range`.

# %%
for i in range(len(beatles)):
    print(beatles[i])

# %% [markdown]
# Adding `tuples`. Make sure both are tuples!

# %%
("john", "paul", "george", "ringo") + ("sebastian")

# %% [markdown]
# Multiplying `tuples`.

# %%
("sebastian", "paul") * 5

# %% [markdown]
# ### Tuple Items
# `tuple` elements may be of any type. `int`, `str`, `float`, `list`, `tuple`, etc.

# %%
subjects = ('bio', 'cs', 'math', 'history')

numbers = (1, 2, 3, 4, 5, 6, 7)

albums = (("Abbey Road", 1969), ("Let It Be", 1970))

# %% [markdown]
# Tuples can also contain elements of more than one type.

# %%
street_address = (164, 'College St.')

record = ('Smith', 'John', (6, 23, 68), ['345-2345', '985-242'])

print(record)

# %% [markdown]
# <a id='section2'></a>
# ## Tuples Are Immutable

# %%
album_1 = ("Sgt. Pepper's Lonely Hearts Club Band", 1967)
album_2 = ("Magical Mystery Tour", 1967)
album_3 = ("The Beatles ('The White Album')", 1968)
album_4 = ("Yellow Submarine", 1969)
album_5 = ("Abbey Road", 1969)
album_6 = ("Let It Be", 1970)

# %%
print(album_6)

# %% [markdown]
# Now, let's say I want to change the date of `"Let It Be"` to 1969.

# %%
album_6[1] = 1969

# %% [markdown]
# Let's convert `album_6` to a list and then try to change the release date to 1969.

# %%
album_6_list = list(album_6)
print(album_6_list)

# %%
album_6_list[1] = 1969
print(album_6_list)

# %% [markdown]
# Consider why a `tuple` is better than a `list` for this example. The Beatles album Let It Be was released in 1970. This fact will never change so by using a `tuple` we protect against any bugs in our code that might unintentionally change the date.
#
# Let's revist some common `list` methods.
#
# | Method | Result |
# | --- | --- |
# | `append()` | dds an element at the end of the list |
# | `clear()` | Removes all the elements from the list |
# | `copy()` | Returns a copy of the list |
# | `count()` | Returns the number of elements with the specified value |
# | `extend()` | Add the elements of a list (or any iterable), to the end of the current list |
# | `index()` | Returns the index of the first element with the specified value |
# | `insert()` | Adds an element at the specified position |
# | `pop()` | Removes the element at the specified position |
# | `remove()` | Removes the first item with the specified value |
# | `reverse()` | Reverses the order of the list |
# | `sort()` | Sorts the list |
#
# Now, let's look at `tuple` methods.
#
# | Method | Result |
# | --- | --- |
# | `count()` | Returns the number of times a specified value occurs in a tuple |
# | `index()` | Searches the tuple for a specified value and returns the position of where it was found |
#
# You'll notice that all of the `list` methods that are used to modify a list are not available for `tuples`. This is because `tuples` are immutable.
#
# Let's take `album_1` and try to add the band name `The Beatles`.

# %%
album_1 = ("Sgt. Pepper's Lonely Hearts Club Band", 1967)
print(album_1)

# %% [markdown]
# Let's try using the `append()` method.

# %%
album_1.append('The Beatles')

# %% [markdown]
# So if I cannot use `append()` or `extend()`, how do we add an element to the end of a tuple?

# %%
list1 = ['apples', 'bananas', 'oranges']
list2 = ['pickles', 'pumpkins']
print(list1)
print(list2)

# %%
list1.extend(list2)
print(list1)

# %% [markdown]
# Because we can't modify `tuples`, we'll need to `add` (`concatenate`) two `tuples` to create a new one.

# %%
tuple1 = ('apples', 'bananas', 'oranges')
tuple2 = ('pickles', 'pumpkins')
print(tuple1)
print(tuple2)

# %% [markdown]
# Let's add these `tuples` together to create a new `tuple`.

# %%
tuple3 = tuple1 + tuple2
print(tuple3)

# %% [markdown]
# Let's write a more compact version of this code using `Assignment Operators`.

# %%
tuple1 = ('apples', 'bananas', 'oranges')
tuple2 = ('pickles', 'pumpkins')

tuple1 += tuple2
print(tuple1)

# %% [markdown]
# We are not adding to `tuple1`. We are concatenating `tuple1` and `tuple2` and assigning the output to a new variable called `tuple1`.

# %%
tuple1 = ('apples', 'bananas', 'oranges')
tuple2 = ('pickles', 'pumpkins')

print(id(tuple1), tuple1)

tuple1 = tuple1 + tuple2
print(id(tuple1), tuple1)

# %% [markdown]
# ### Nested Tuples and Immutability
#
# Immutable means that the item reference addresses contained in a tuple cannot be changed after the tuple has been created. However, if the element of a tuple is mutable, it can be changed.

# %%
life = (['Canada', 76.5], ['United States', 75.5], ['Mexico', 72.0])
print(life)

# %% [markdown]
# #### Will this work?

# %%
life[0] = ['Canada', 80.0]

# %% [markdown]
# Here we have a tuple of lists. We can't change the tuple elements. But we can change the list elements that are inside because lists are mutable.

# %%
life = (['Canada', 76.5], ['United States', 75.5], ['Mexico', 72.0])
print(life)

# %% [markdown]
# #### Will this work?

# %%
life[0][1] = 80.0
print(life)

# %% [markdown]
# #  Breakout Session

# %%
# PART 1

# Use a range of indexes to print the `third`, `fourth`, and `fifth` item in the tuple.

fruits = ("apple", "banana", "cherry", "orange", 
          "kiwi", "melon", "mango")

# WRITE CODE HERE

# PART 2
# Use negative indexing to print the second last item in the tuple.

fruits = ("apple", "banana", "cherry")

# PART 3
# Create a new variable called fruits_rev and assign the reverse of fruits to it.

fruits = ("apple", "banana", "cherry", "orange", 
          "kiwi", "melon", "mango")

# PART 4
# Create a new tuple called shopping_list and assign to it the second, third and fourth items of fruits and the last 3 items of vegetables in the order they occur in vegetables. 
fruits = ("apple", "banana", "cherry", "orange", 
          "kiwi", "melon", "mango")
vegetables = ("Potatoes", "Broccoli", "Beets", "Eggplant")

# %% [markdown]
# <a id='section3'></a>
# ## Unpacking Tuples
# Python has a very nice tuple assignment feature that allows you to, essentially, assign multiple variables at once. Remember, we want to write `#cleancode` and the less code the better.

# %%
x = 4.2
y = 0.1
z = 4.5
print(x)
print(y)
print(z)

# %%
x, y, z = 4.2, 0.1, 4.5
print(x)
print(y)
print(z)

# %% [markdown]
# Another benefit to tuples is that you can always unpack tuples successfully because you always know how many items are in them (Immutability).

# %%
data = (0.2, 1.3, 40.2)
x, y, z = data
print(x)
print(y)
print(z)

# %% [markdown]
# The same does not go for lists. See the example below:

# %%
data = [0.2, 1.3, 40.2]
#data.append(4.1)
x, y, z = data
print(x)
print(y)
print(z)

# %% [markdown]
# <a id='section4'></a>
# ## Tuples as `return` Values
# ### Function `return` Example 1

# %%
import math

def area_circumference(radius): 
    """
    (float) -> float, float
    Return the circumference and area of a circle of a specified radius.
    """
    circumference = 2 * math.pi * radius 
    area = math.pi * radius * radius

# %% [markdown]
# #### What is `return`ed?

# %%
output = area_circumference(10)
print(output, type(output))

# %% [markdown]
# ### Function `return` Example 2

# %%
import math

def area_circumference(radius): 
    """
    (float) -> float, float
    Return the circumference and area of a circle of a specified radius.
    """
    circumference = 2 * math.pi * radius 
    area = math.pi * radius * radius 
    
    return area

# %% [markdown]
# #### What is `return`ed?

# %%
output = area_circumference(10)
print(output, type(output))

# %% [markdown]
# ### Function `return` Example 3

# %%
import math

def area_circumference(radius): 
    """
    (float) -> float, float
    Return the circumference and area of a circle of a specified radius.
    """
    circumference = 2 * math.pi * radius 
    area = math.pi * radius * radius 
    
    return circumference, area

# %% [markdown]
# #### What is `return`ed?

# %%
output = area_circumference(10)
print(output, type(output))

# %% [markdown]
# ### Function `return` Example 4

# %%
import math

def area_circumference(radius): 
    """
    (float) -> float, float
    Return the circumference and area of a circle of a specified radius.
    """
    circumference = 2 * math.pi * radius 
    area = math.pi * radius * radius 
    
    return circumference, area

# %% [markdown]
# #### What is `return`ed?

# %%
circumference, area = area_circumference(10)
print(circumference, type(circumference))
print(area, type(area))

# %% [markdown]
# # Breakout Session 2
#
# Below are some musical albums. The artist, album, and release year are presented in `tuples`. In the cell below, place these tuples in a `container` and assign it to a variable called `albums`. Then loop through the albums and print the artist, album, and year. You must use `tuple` unpacking.

# %%
("The Beatles", "Sgt. Pepper's Lonely Hearts Club Band", 1967)
("Wintersleep", "Welcome to the Night Sky", 2007)
("The Tragically Hip", "In Between Evolution", 2004)
("Tom Petty", "Wildflowers", 1994)
("The Traveling Wilburys", "Traveling Wilburys Vol. 1", 1988)
("George Harrison", "All Things Must Pass", 1970)
("Queen", "A Night At The Opera", 1975)

# place these tuples in a container and assign it to a variable called albums. You need to decide if a list or tuple appropriate.

# loop through the albums and print the artist, album, and year. You must use `tuple` unpacking.

# %% [markdown]
# <a id='section5'></a>
# ## Sets
# Sets are great for performing the mathematical operations: union, intersection, and difference. These are all implemented as methods shown in the following table.
#
# Operation	| Equivalent	| Result
# ------------|:---------------:|-------
# len(s) |N/A | number of elements in set s (cardinality)
# x in s |N/A | test x for membership in s
# x not in s |N/A|test x for non-membership in s
# s.issubset(t) |	s <= t|test whether every element in s is in t
# s.issuperset(t)|s >= t|test whether every element in t is in s
# s.union(t)|	s &#124; t| new set with elements from both s and t
# s.intersection(t) |s & t|new set with elements common to s and t
# s.difference(t)|s - t|new set with elements in s but not in t
# s.symmetric_difference(t)|s ^ t|new set with elements in either s or t but not both
# s.copy()|N/A|new set with a copy of s
#
# Let's create the two `sets` of North American and European cars from the slides.

# %%
north_america = {'Mercedes', 'Tesla', 'Chrysler', 'Dodge', 'BMW', 'Ford'}
europe = {'Mercedes', 'Tesla', 'Renault', 'Peugeot', 'BMW', 'Ford'}

# %% [markdown]
# #### `sets` are unordered
# As you'll recall, `sets` are unordered as opposed to `tuples` and `lists`.

# %%
print(north_america)

# %%
print(europe)

# %% [markdown]
# So, `sets` are unordered, but can we index or slice them?

# %%
europe[0]

# %% [markdown]
# But if we conver to a list, we can because lists are ordered.

# %%
list(europe)[0]

# %% [markdown]
# Order does not matter when you are comparing whether two sets are the same.

# %%
animals1 = {'bird', 'goat', 'tiger'}
animals2 = {'goat', 'tiger', 'bird'}

animals1 == animals2

# %% [markdown]
# #### Membership

# %%
'Nissan' in europe

# %%
'Tesla' in europe

# %% [markdown]
# #### Union

# %%
north_america.union(europe)

# %%
europe.union(north_america)

# %%
north_america | europe

# %%
europe | north_america

# %% [markdown]
# #### Intersection

# %%
north_america.intersection(europe)

# %%
europe.intersection(north_america)

# %%
north_america & europe

# %%
europe & north_america

# %% [markdown]
# #### `sets` are iterable

# %%
north_america = {'Mercedes', 'Tesla', 'Chrysler', 'Dodge', 'BMW', 'Ford'}

for car in north_america:
    print(car)

# %% [markdown]
# ### Practical Applications of `sets`
# We want to create a collection of unique birds from the observations made during a birding (bird watching) trip.

# %%
observations = ("canada goose", "canada goose", "long-tailed jaeger",
                "canada goose", "snow goose", "canada goose", 
                "long-tailed jaeger", "canada goose", "northern fulmar")

# %% [markdown]
# I could loop through the `tuple` and collect all the unique birds.

# %%
birds = []
for observation in observations:
    if observation not in birds:
        birds.append(observation)
        
print(birds)

# %%
birds = set(observations)
print(birds)

# %% [markdown]
# <a id='section6'></a>
# ## Dictionaries
#
# Dictionaries are data structures used to store data as key-value pairs, where each unique key maps directly to a specific value. For example, we can store student grades like this:

# %%
grades = {'Tina': 'A+', 'Brad': 'C-'}
print(grades)

# %% [markdown]
# We can even place dictionaries within dictionaries.

# %%
users = {'0323442785': {'first name': 'Sebastian',
                        'last name': 'Goodfellow',
                        'address': '555 Code Street',
                        'phone number': '555-7654'},
         '9764327492': {'first name': 'Ben',
                        'last name': 'Kinsella',
                        'address': '555 Python Street',
                        'phone number': '555-2345'}}
print(users)

# %% [markdown]
# <a id='section7'></a>
# ## Dictionary Operations
# The table below shows some common `dictionary` operations.
#
# Operation|Description|Example code
# ---------|-----------|------------
# my_dict[key]|Indexing operation – retrieves the value associated with key.|john_grade = my_dict['John']
# my_dict[key] = value|Adds an entry if the entry does not exist, else modifies the existing entry.|	my_dict['John'] = 'B+'
# del my_dict[key]|Deletes the key:value from a dict.|del my_dict['John']
# key in my_dict|Tests for existence of key in my_dict|if 'John' in my_dict:   ...
#
# Let's start with the following `dictionary`.

# %%
grades = {'Tina': 'A+', 'Omid': 'A-', 'Lenny': 'B-', 'Maggie': 'C+'}
print(grades)

# %% [markdown]
# #### Indexing
# Retrieve the `value` associated with a `key`.

# %%
print(grades['Omid'])

# %%
print(grades['Maggie'])

# %%
print(grades['Ben'])

# %% [markdown]
# #### Add or Modify Entry
# Add an entry if the entry does not exist, otherwise it modifies the existing entry.

# %%
print(grades)

# %%
grades['Lenny'] = 'B'
print(grades)

# %% [markdown]
# Add a `key: value` pair for `'Ben'`.

# %%
grades['Ben'] = 'F'
print(grades)

# %% [markdown]
# #### Delete Entry
# Removes the key and it’s value from a dictionary.

# %%
print(grades)

# %%
del grades['Ben']
print(grades)

# %% [markdown]
# #### Check for `key`
# Tests for existence of key in the dictionary (it does not check the values).
#
# Check to see if `'Tina'` is in the `dictionary`.

# %%
'Tina' in grades

# %% [markdown]
# Check to see if `'Ben'` is in the `dictionary`.

# %%
'Ben' in grades

# %% [markdown]
# Lastly, let's check to see if the grade `'A+'` is in the `dictionary`.

# %%
'A+' in grades

# %% [markdown]
# #### Indexing Nested Dictionaries
# Dictionaries can, of course, be nested.

# %%
students = {}
print(students)

# %%
students["John"] = {"Grade": "A+", "StudentID": 22321}
print(students)

# %% [markdown]
# - The variable `students` is first created as an empty dictionary.
# - Then a new entry is added with the key `'John'` and the value associated with `John` is another dictionary.
# - Indexing operations can be applied to the nested dictionary by using consecutive sets of brackets `[][][][]` just like for nested lists.

# %%
print(students)

# %%
print(students["John"])

# %%
print(students["John"]["Grade"])

# %% [markdown]
# #### Quick Aside on { } and Sets.

# %%
data = {'Ben': 'F'}
print(type(data))

# %%
data = {'ford', 'tesla', 'bmw'}
print(type(data))

# %%
data = {}
print(type(data))

# %% [markdown]
# How do we create an empty set?

# %%
data = set()
print(type(data))

# %% [markdown]
# <a id='section8'></a>
# ## Dictionary Methods
# Like `lists`, `tuples`, and `sets`, `dictionaries` are objects and have methods that can be applied on them.
#
# Let's look at some examples.
#
# ### `.keys()`
# Returns a set-like object containing all keys found in a given dictionary.

# %%
friends = {"Bob": 32, "Jane": 42, 'Juan': 38}
print(friends)

# %%
print(friends.keys())

# %% [markdown]
# ### `.values()`
# Returns a list-like object containing all values found in a given dictionary.

# %%
friends = {"Bob": 32, "Jane": 42, 'Juan': 38}
print(friends)

# %%
print(friends.values())

# %% [markdown]
# ### `.items()`
# Returns a list-like object containing tuples of `key-value-pairs`.

# %%
friends = {"Bob": 32, "Jane": 42, 'Juan': 38}
print(friends)

# %%
print(friends.items())

# %% [markdown]
# ### `.clear()`
# Remove all the elements from a dictionary.

# %%
friends = {"Bob": 32, "Jane": 42, 'Juan': 38}
print(friends)

# %%
friends.clear()
print(friends)

# %% [markdown]
# ### `.get()`
# Returns the value of the key entry from the dict.

# %%
friends = {"Bob": 32, "Jane": 42, 'Juan': 38}
print(friends)

# %% [markdown]
# Let's try getting the `value` for `'Jane'`.

# %%
print(friends.get('Jane'))

# %% [markdown]
# Now, let's try getting the `value` for a `key` that doesn't exist.

# %%
print(friends.get('Ava'))

# %% [markdown]
# If we want to specify what gets returned if the `key` doesn't exist, we can include a second argument.

# %%
print(friends.get('Ava', 'N/A'))

# %% [markdown]
# `.get` is a lot like `dict['key']` but it will handle the key not existing without throwing an error.

# %%
print(friends['Ava'])

# %% [markdown]
# ### `.update()`
# Merges a dictionary `dict_1` with another dictionary `dict_2`. Existing entries in `dict_1` are overwritten if the same keys exist in `dict_2`.

# %%
dict_1 = {"Bob": 32, "Jane": 42, 'Juan': 38}
dict_2 = {'Seb': 36, 'Ben': 30}
print(dict_1)
print(dict_2)

# %%
dict_1.update(dict_2)
print(dict_1)

# %% [markdown]
# Existing entries in `dict_1` are overwritten if the same keys exist in `dict_2`.
#
# Let's try again with a the key `Seb` being in each dictionary.

# %%
dict_1 = {"Bob": 32, "Jane": 42, 'Juan': 38, 'Seb': 25}
dict_2 = {'Seb': 36, 'Ben': 30}
print(dict_1)
print(dict_2)

# %%
dict_1.update(dict_2)
print(dict_1)

# %% [markdown]
# ### `.pop()`
# Removes and returns the `value` corresponding to the specified `key` from the dictionary. If `key` does not exist, then `None` or a user-specified default is returned.

# %%
friends = {"Bob": 32, "Jane": 42, 'Juan': 38}
print(friends)

# %%
val = friends.pop("Bob")
print(val)
print(friends)

# %%
val2 = friends.pop("John", "N/A")
print(val2)
print(friends)

# %%
val2 = friends.pop("John")
print(val2)
print(friends)

# %% [markdown]
# # Breakout Session

# %%
# PART 1
# Merge two Python dictionaries dict1 and dict2 into one.

dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# WRITE YOUR CODE HERE



# PART 2
# Write a Python expression that evaluated to True if the value 200 exists in the keys or values of dict4.

dict4 = {'a': 100, 'b': 200, 'c': 300}

# WRITE YOUR CODE HERE



# PART 3
# Write a program to rename the 'city' key to be called 'location' in the following dictionary.

dict5 = {
  "name": "Seb",
  "age": 36,
  "salary": 8000,
  "city": "Toronto"
}

# WRITE YOUR CODE HERE

# %% [markdown]
# <a id='section9'></a>
# ## Iterating
# Let's start with a dictionary of employee information.

# %%
employees = {
    'emp1': {'name': 'John', 'salary': 7500},
    'emp2': {'name': 'Emma', 'salary': 8000},
    'emp3': {'name': 'Brad', 'salary': 5300},
    'emp4': {'name': 'Ava', 'salary': 9870},
    'emp5': {'name': 'Qi', 'salary': 2450},
    'emp6': {'name': 'Ben', 'salary': 4560},
    'emp7': {'name': 'Seb', 'salary': 8900}
}

# %% [markdown]
# ### Default: `for key in employees:`
# The default interation for a dicitonary is over the `keys`.

# %%
for employee in employees:
    print(employee)

# %% [markdown]
# ### Keys: `for key in employees.key():`
# If you want to be explicit and write slightly more readable code, you can use the `.keys()` method.

# %%
for employee in employees.keys():
    print(employee)

# %% [markdown]
# ### Values: `for value in employees.values():`
# To iterature through the dictionary values, you can use the `.values()` method.

# %%
for employee_info in employees.values():
    print(employee_info)

# %% [markdown]
# ### Item: `for item in employees.items():`
# If you want to iterate through the items (key:value pairs) in a dictionary, you can use the `.items()` method.

# %%
for item in employees.items():
    print(item)

# %% [markdown]
# You can see that we get a bunch of `tuples` and we learned that we can unpack them.

# %%
for employee, employee_info in employees.items():
    print(employee, '   ', employee_info)

# %% [markdown]
# <a id='section10'></a>
# ## Dictionary Inversion
# Reversing a dictionary is not the same as reversing a list; it entails inverting or switching the dictionary's key and value parts.
#
# Let's consider our `eng2spa` dictionary.

# %%
eng2spa = {"two": "dos", "one": "uno"}

# %% [markdown]
# Now, let's try to invert it so it looks like this:
# ```python
# spa2eng = {"dos": "two", "uno": "one"}
# ```

# %%
spa2eng = {}

for eng_word in eng2spa:
    spa_word = eng2spa[eng_word]
    spa2eng[spa_word] = eng_word
    
print(spa2eng)

# %% [markdown]
# Let's try the same thing with a more complex dictionary of movies (`keys`) and lead actors (`values`).

# %%
movies = {
    'Inception': 'Leonardo DiCaprio',
    'Titanic': 'Leonardo DiCaprio',
    'Snatch': 'Brad Pitt',
    'I, Tonya': 'Margo Robbie',
    'Moneyball': 'Brad Pitt', 
    'Troy': 'Brad Pitt',
    'The Revenant': 'Leonardo DiCaprio' 
}

# %%
actors = {}

for movie in movies:
    actor = movies[movie]
    actors[actor] = movie
    
print(actors)

# %% [markdown]
# # Breakout Session
#
# What should you notice about the inverted dictionary? How do we fix this?
#
# This is what I want:
#
# ```python
# {
#     "Brad Pitt": [
#         "Snatch",
#         "Moneyball",
#         "Troy"
#     ],
#     "Leonardo DiCaprio": [
#         "Inception",
#         "Titanic",
#         "The Revenant"
#     ],
#     "Margo Robbie": [
#         "I, Tonya"
#     ]
# }
# ```

# %%
actors = {}

for movie in movies:
    
    actor = movies[movie]
    

    
print(actors)

# %% [markdown]
# <a id='section11'></a>
# ## Dictionaries as Data Structures
# `Dictionaries` are useful as `"quick and dirty"` data structures.
#
# For production code that will be used and maintained for a long time it would be better to use `objects` - we'll see those in a few weeks.
#
# Below is a dictionary (indexed by a string - the students name), with another `dictionary` as a value, index by strings `'Homework'`, `'Midterm'`, `'Final'` and with elements (of the inner `dictionary` being lists and ints)

# %%
students = {
    'John Ponting': {
        'Homework': [79, 80, 74],
        'Midterm': 85,
        'Final': 92
    },
    'Jacqueline Kallis': {
        'Homework': [90, 92, 65],
        'Midterm': 87,
        'Final': 75
    },
    'Ricky Bobby': {
        'Homework': [50, 52, 78],
        'Midterm': 40,
        'Final': 65
    },
}

# %% [markdown]
# Let's say a students `course_mark` is calculated using the following formula.
#
# ```python
# course_mark = (0.1 * averge homework mark) + (0.4 * midterm mark) + (0.5 * final mark)
# ```
# Let's write some code to calculate the `course_mark` for a student specificed by user input.

# %%
user_input = ''

while user_input != 'exit':    
    
    user_input = input('Enter student name: ')
    
    if user_input in students.keys():

        # Get values from nested dict
        homework = students[user_input]['Homework']
        midterm = students[user_input]['Midterm']
        final = students[user_input]['Final']

        # Compute student course mark 
        course_mark = (0.1 * sum(homework) / len(homework) + 
                       0.4 * midterm + 
                       0.5 * final)

        # Print course mark
        print(user_input, "'s final mark is:", course_mark, '\n')
        
    else:
        print(user_input, 'is not a student in this course.\n')
